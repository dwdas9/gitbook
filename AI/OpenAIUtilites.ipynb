# %%
from openai import OpenAI
import os

def list_failed_files(vector_store_id):
    """
    Lists all files that failed to upload to a specified vector store.

    Args:
        vector_store_id: The ID of the vector store.
    """
    api_key = "yourkey"  # Ensure your API key is set as an environment variable

    # Instantiate the OpenAI client with your API key
    client = OpenAI(api_key=api_key)

    try:
        # Use the client to list files in the vector store
        vector_store_files = client.beta.vector_stores.files.list(
            vector_store_id=vector_store_id
        )

        # Print the full response to inspect its structure
        print("Full API response:")
        print(vector_store_files)

        # Check if 'data' key exists in the response
        if 'data' in vector_store_files:
            failed_files = [file for file in vector_store_files['data'] if file['status'] == "failed"]

            if failed_files:
                print("Failed files:")
                for file in failed_files:
                    print(f"  - ID: {file['id']}")
                    print(f"    Created at: {file['created_at']}")
                    if 'last_error' in file and file['last_error']:
                        print(f"    Error: {file['last_error']}")
            else:
                print("No failed files found.")
        else:
            print("Error: 'data' key not found in the response.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
vector_store_id = "id"  # Replace with your actual vector store ID
list_failed_files(vector_store_id)
# Out:
# An error occurred: Error code: 404 - {'error': {'message': "No vector store found with id 'vs_2cTvzvh6gEtquvYU0N17u2Fs'.", 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
from openai import OpenAI
import os

def list_and_delete_failed_files(vector_store_id):
    """
    Lists and deletes files that failed to upload to a specified vector store.

    Args:
        vector_store_id: The ID of the vector store.
    """
    api_key = "yourkey"  # Ensure your API key is set as an environment variable

    # Instantiate the OpenAI client with your API key
    client = OpenAI(api_key=api_key)

    try:
        # Use the client to list files in the vector store
        vector_store_files = client.beta.vector_stores.files.list(
            vector_store_id=vector_store_id
        )

        # Iterate through the files and identify those with status 'failed'
        failed_files = [file for file in vector_store_files if file.status == 'failed']

        if failed_files:
            print(f"Found {len(failed_files)} failed files. Deleting them...")

            for file in failed_files:
                # Print details about the failed file
                print(f"  - ID: {file.id}")
                print(f"    Created at: {file.created_at}")
                print(f"    Error message: {file.last_error.message if file.last_error else 'None'}")

                # Delete the failed file
                deleted_file = client.beta.vector_stores.files.delete(
                    vector_store_id=vector_store_id,
                    file_id=file.id
                )
                print(f"Deleted file: {deleted_file.id}")

        else:
            print("No failed files found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
vector_store_id = "id"  # Replace with your actual vector store ID
list_and_delete_failed_files(vector_store_id)
# Out:
# An error occurred: Error code: 404 - {'error': {'message': "No vector store found with id 'vs_2cTvzvh6gEtquvYU0N17u2Fs'.", 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
# Code to delete files from your projects store**. Works 100%. 
from openai import OpenAI

# This part is important make sure you provide the key for the right project get it from https://platform.openai.com/api-keys

api_key = "yourkey"  # Ensure your API key is set as an environment variable

# Instantiate the OpenAI client with your API key
client = OpenAI(api_key=api_key)

organization_id = "id"  # Replace this with your organization ID


def delete_all_files():
    """
    Deletes all files in the organization by listing and deleting each one.
    """
    try:
        # List all files in the organization
        files = client.files.list()

        # Iterate through the files and delete each one
        files_found = False
        for file in files:
            files_found = True
            file_id = file.id  # Access the file ID
            print(f"Deleting file: {file_id}")
            
            # Delete the file
            client.files.delete(file_id)
            print(f"File {file_id} deleted successfully.")

        if not files_found:
            print("No files found in the organization.")
        
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function to delete all files
delete_all_files()
# Out:
# Deleting file: file-8LE8qiDgCKdKNAxEppgBcO94
# File file-8LE8qiDgCKdKNAxEppgBcO94 deleted successfully.
# Deleting file: file-dOmxEwRpoO1zKSj91D1GiI8z
# File file-dOmxEwRpoO1zKSj91D1GiI8z deleted successfully.
# Deleting file: file-9ZXWTAs2D6DhH7asCP3QLyvt
# File file-9ZXWTAs2D6DhH7asCP3QLyvt deleted successfully.
# Deleting file: file-gzLOzziqcbeenoJjNkkNvhcq
# File file-gzLOzziqcbeenoJjNkkNvhcq deleted successfully.
# Deleting file: file-jFZwVRyYweTcAV1M2bD1t0UU
# File file-jFZwVRyYweTcAV1M2bD1t0UU deleted successfully.
# Deleting file: file-RCfg2L5X5TyrV2zAiPShB5tI
# File file-RCfg2L5X5TyrV2zAiPShB5tI deleted successfully.
# Deleting file: file-KJPhouKn5y1JcNEeg01k3xKI
# File file-KJPhouKn5y1JcNEeg01k3xKI deleted successfully.
# Deleting file: file-IFoJB9oKRfrGuacSc4vidxQg
# File file-IFoJB9oKRfrGuacSc4vidxQg deleted successfully.
# Deleting file: file-IQ2gfiDzpl7GJJpAxseTo8cj
# File file-IQ2gfiDzpl7GJJpAxseTo8cj deleted successfully.
# Deleting file: file-4U1MY8ZDPnz23LH0PSLGoPxU
# File file-4U1MY8ZDPnz23LH0PSLGoPxU deleted successfully.
# Deleting file: file-mASQNDqtkJJ9ndnRjrpNa12V
# File file-mASQNDqtkJJ9ndnRjrpNa12V deleted successfully.
# Deleting file: file-t1yMHlO5OkZE1Q4jNTm9Z0oE
# File file-t1yMHlO5OkZE1Q4jNTm9Z0oE deleted successfully.
# Deleting file: file-y3bHPHtTBFenEAlqd8ci7wfG
# File file-y3bHPHtTBFenEAlqd8ci7wfG deleted successfully.
# Deleting file: file-g2taaVRAnLHjASwqEeUrbwUH
# File file-g2taaVRAnLHjASwqEeUrbwUH deleted successfully.
# Deleting file: file-iq7DKJszVf68ldmVEjjLaZOJ
# File file-iq7DKJszVf68ldmVEjjLaZOJ deleted successfully.
# Deleting file: file-IboOEPlG8y5DawIa9hjk5Kfu
# File file-IboOEPlG8y5DawIa9hjk5Kfu deleted successfully.
# Deleting file: file-fU1aMDAja9f8e5FgqW4w3USr
# File file-fU1aMDAja9f8e5FgqW4w3USr deleted successfully.
# Deleting file: file-5DjXvYFRtvzENUBBnR0w6QET
# File file-5DjXvYFRtvzENUBBnR0w6QET deleted successfully.
# Deleting file: file-HN8pEeS2ap7tHZYMyM6MhyFb
# File file-HN8pEeS2ap7tHZYMyM6MhyFb deleted successfully.
# Deleting file: file-0F9QZ7vKx8XnPciTGZFepy4u
# File file-0F9QZ7vKx8XnPciTGZFepy4u deleted successfully.
# Deleting file: file-OIqOJEzmoq0cVwwGed3Vp8XZ
# File file-OIqOJEzmoq0cVwwGed3Vp8XZ deleted successfully.
# Deleting file: file-m50h5RZlear4a4fYGLha9arW
# File file-m50h5RZlear4a4fYGLha9arW deleted successfully.
# Deleting file: file-ezdic5NCmxo72sysCaCpdAL1
# File file-ezdic5NCmxo72sysCaCpdAL1 deleted successfully.
# Deleting file: file-gQplD7c4eBJHYf0k5Ir8Oe5Z
# File file-gQplD7c4eBJHYf0k5Ir8Oe5Z deleted successfully.
# Deleting file: file-OC990pddIbGB8f5ZiPdrPwXb
# File file-OC990pddIbGB8f5ZiPdrPwXb deleted successfully.
# Deleting file: file-5fFZorti45wzTA8H5PD39ADb
# File file-5fFZorti45wzTA8H5PD39ADb deleted successfully.
# Deleting file: file-B8Y0PJshx3QZJpt93kMxBIvb
# File file-B8Y0PJshx3QZJpt93kMxBIvb deleted successfully.
# Deleting file: file-AlM4s6ghjXsz9Cus84GXMFxE
# File file-AlM4s6ghjXsz9Cus84GXMFxE deleted successfully.
# Deleting file: file-MzhEALDgsj7pZlrtet8nm6da
# File file-MzhEALDgsj7pZlrtet8nm6da deleted successfully.
# Deleting file: file-9aMt8TUdkf5fwZzMWyrgo9lV
# File file-9aMt8TUdkf5fwZzMWyrgo9lV deleted successfully.
# Deleting file: file-QeqsX9XaeVpXGhwYIrUNv2k2
# File file-QeqsX9XaeVpXGhwYIrUNv2k2 deleted successfully.
# Deleting file: file-GdrvZvK66KtYn3JkZTH8G9oE
# File file-GdrvZvK66KtYn3JkZTH8G9oE deleted successfully.
# Deleting file: file-b1uh2VLIj73BBBect5rNQFvu
# File file-b1uh2VLIj73BBBect5rNQFvu deleted successfully.
# Deleting file: file-77dMvrCSB3HgxFfioCqVHJER
# File file-77dMvrCSB3HgxFfioCqVHJER deleted successfully.
# Deleting file: file-rFgJRef08mawsOBuljHMxIFe
# File file-rFgJRef08mawsOBuljHMxIFe deleted successfully.
# Deleting file: file-HQdehJKPnfxF3vqJby5Rh9R1
# File file-HQdehJKPnfxF3vqJby5Rh9R1 deleted successfully.
# Deleting file: file-GZmblgz90XMeG1lxwDXcSStP
# File file-GZmblgz90XMeG1lxwDXcSStP deleted successfully.
# Deleting file: file-Mt8qPSKoQalOMSCikMF0SMoD
# File file-Mt8qPSKoQalOMSCikMF0SMoD deleted successfully.
# Deleting file: file-dH4iaChniMuXJisaW66XB8gq
# File file-dH4iaChniMuXJisaW66XB8gq deleted successfully.
# Deleting file: file-KrzdrQW6H0Kgjq1s2AMHyN3z
# File file-KrzdrQW6H0Kgjq1s2AMHyN3z deleted successfully.
# Deleting file: file-g08JwAdLangFxWq545xe2YRY
# File file-g08JwAdLangFxWq545xe2YRY deleted successfully.
# Deleting file: file-8IsvBQBKu1qZvgK6RSRdzX9a
# File file-8IsvBQBKu1qZvgK6RSRdzX9a deleted successfully.
# Deleting file: file-82AfF1C6mnJzEmCE6YLg4XO2
# File file-82AfF1C6mnJzEmCE6YLg4XO2 deleted successfully.
# Deleting file: file-0WL8V53tLC8I40Djty76WUcz
# File file-0WL8V53tLC8I40Djty76WUcz deleted successfully.
# Deleting file: file-i0jiMoiiSD25XIQJBffwc6AS
# File file-i0jiMoiiSD25XIQJBffwc6AS deleted successfully.
# Deleting file: file-5qBoQtkm9qPGH10LlGQn1Qkk
# File file-5qBoQtkm9qPGH10LlGQn1Qkk deleted successfully.
# Deleting file: file-MVsACIf649kjTD1nrEzZXYwk
# File file-MVsACIf649kjTD1nrEzZXYwk deleted successfully.
# Deleting file: file-rHMqPi5gCzjgbNco5VHyVNf9
# File file-rHMqPi5gCzjgbNco5VHyVNf9 deleted successfully.
# Deleting file: file-HrRZueTCrEQWEy6HmPXOqIk8
# File file-HrRZueTCrEQWEy6HmPXOqIk8 deleted successfully.
# Deleting file: file-ctqQMO0xVRemTxYi0M8CIwxC
# File file-ctqQMO0xVRemTxYi0M8CIwxC deleted successfully.
# Deleting file: file-QENoXTH46aTEGsef9mCXl2Ee
# File file-QENoXTH46aTEGsef9mCXl2Ee deleted successfully.
# Deleting file: file-TLDVUTcmJpntsDGFScoL3AoR
# File file-TLDVUTcmJpntsDGFScoL3AoR deleted successfully.
# Deleting file: file-PPNl6wzqHiSecjxnzdrnSChE
# File file-PPNl6wzqHiSecjxnzdrnSChE deleted successfully.
# Deleting file: file-18eVUjfZNbMCgXA6SPdKXE0y
# File file-18eVUjfZNbMCgXA6SPdKXE0y deleted successfully.
# Deleting file: file-dPSpL7CqOyPsvnEoyMjDUHtG
# File file-dPSpL7CqOyPsvnEoyMjDUHtG deleted successfully.
# Deleting file: file-bJo3CTQeP3an3FwVnbMiu4mx
# File file-bJo3CTQeP3an3FwVnbMiu4mx deleted successfully.
# Deleting file: file-euzbxhSftXjLNOykBiHYJucU
# File file-euzbxhSftXjLNOykBiHYJucU deleted successfully.
# Deleting file: file-2M9L0Lq6gt0KXQAznhV2gqVY
# File file-2M9L0Lq6gt0KXQAznhV2gqVY deleted successfully.
# Deleting file: file-AW8JRWQw7YbDrbKxam20G35g
# File file-AW8JRWQw7YbDrbKxam20G35g deleted successfully.
# Deleting file: file-eSYgiZxqlVnvsbiv5dlXKRmz
# File file-eSYgiZxqlVnvsbiv5dlXKRmz deleted successfully.
# Deleting file: file-HITz19L27tgnOFyukA0pF1xt
# File file-HITz19L27tgnOFyukA0pF1xt deleted successfully.
# Deleting file: file-NNp1arUzbEg7FaYLsYbgitSI
# File file-NNp1arUzbEg7FaYLsYbgitSI deleted successfully.
# Deleting file: file-0xacALdqFQl1pnU1wSZItlZ2
# File file-0xacALdqFQl1pnU1wSZItlZ2 deleted successfully.
# Deleting file: file-7jlNxkVdRzBRPZbrLFhMXso9
# File file-7jlNxkVdRzBRPZbrLFhMXso9 deleted successfully.
# Deleting file: file-mpUGdehvlMVoT1qG314dhz4z
# File file-mpUGdehvlMVoT1qG314dhz4z deleted successfully.
